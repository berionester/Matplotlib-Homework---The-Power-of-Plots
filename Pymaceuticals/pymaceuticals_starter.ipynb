# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
# !pip install seaborn
# !pip install sklearn
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np
import sklearn.linear_model
import scipy.stats as st

# Study data files
Mouse_metadata_path = "data/Mouse_metadata.csv"
Study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
Mouse_metadata = pd.read_csv(Mouse_metadata_path)
Study_results = pd.read_csv(Study_results_path)

# Combine the data into a single dataset
mice_data = pd.merge(pd.read_csv(Mouse_metadata_path),
                     pd.read_csv(Study_results_path),
                     how='outer', on='Mouse ID')

# Display the data table for preview
mice_data.head(10)
# Out:
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\cetin\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\cetin\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
# 5     k403     Ramicane  Male          21          16         25
# 6     k403     Ramicane  Male          21          16         30
# ...

# %%
# Checking the number of mice.
print(f"The number of unique mice IDs in dataset: {len(pd.unique(mice_data['Mouse ID']))}")
# Out:
# The number of unique mice IDs in dataset: 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
mouse_ID_duplicates = mice_data[mice_data.duplicated(["Mouse ID","Timepoint"])]
mouse_ID = pd.DataFrame({"Mouse ID":mouse_ID_duplicates["Mouse ID"].unique()})
mouse_ID =str(mouse_ID.iloc[0,0])
print (f"The duplicated Mouse IDs in dataset: {mouse_ID}.")
# Out:
# The duplicated Mouse IDs in dataset: g989.

# %%
 # Optional: Get all the data for the duplicate mouse ID.
 mice_data.loc[mice_data["Mouse ID"]==mouse_ID,:]
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
mice_cleaned_data = mice_data.drop(mice_data[mice_data["Mouse ID"]==mouse_ID].index)
mice_cleaned_data.reset_index(inplace=True)

# %%
# Checking the number of mice in the clean DataFrame.
print(f"The clean number of unique Mice IDs in dataset: {len(pd.unique(mice_cleaned_data['Mouse ID']))}.")
# Out:
# The clean number of unique Mice IDs in dataset: 248.

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

statistics_table_1= pd.DataFrame({"Mean": 
                         mice_cleaned_data.groupby('Drug Regimen').mean()['Tumor Volume (mm3)'].map("{:,.2f}".format),
                         "Median": 
                         mice_cleaned_data.groupby('Drug Regimen').median()['Tumor Volume (mm3)'].map("{:,.2f}".format),
                         "Variance": 
                         mice_cleaned_data.groupby('Drug Regimen').var()['Tumor Volume (mm3)'].map("{:,.2f}".format),
                         "Standard Deviation": 
                         mice_cleaned_data.groupby('Drug Regimen').std()['Tumor Volume (mm3)'].map("{:,.2f}".format),
                         "SEM":
                         mice_cleaned_data.groupby('Drug Regimen').sem()['Tumor Volume (mm3)'].map("{:,.2f}".format),
                        })
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.
statistics_table_1
# Out:
#                Mean Median Variance Standard Deviation   SEM
# Drug Regimen
# Capomulin     40.68  41.56    24.95               4.99  0.33
# Ceftamin      52.59  51.78    39.29               6.27  0.47
# Infubinol     52.88  51.82    43.13               6.57  0.49
# Ketapril      55.24  53.70    68.55               8.28  0.60
# Naftisol      54.33  52.51    66.17               8.13  0.60
# Placebo       54.03  52.29    61.17               7.82  0.58
# Propriva      52.32  50.45    43.85               6.62  0.54
# Ramicane      40.22  40.67    23.49               4.85  0.32
# Stelasyn      54.23  52.43    59.45               7.71  0.57
# Zoniferol     53.24  51.82    48.53               6.97  0.52

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line
statistics_table_2 = mice_cleaned_data.groupby('Drug Regimen')
summary_stats_table_2 = statistics_table_2.agg(['mean','median','var','std','sem'])["Tumor Volume (mm3)"]
summary_stats_table_2
# Out:
# C:\Users\cetin\AppData\Local\Temp\ipykernel_7984\1590337933.py:5: FutureWarning: ['Mouse ID', 'Sex'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   summary_stats_table_2 = statistics_table_2.agg(['mean','median','var','std','sem'])["Tumor Volume (mm3)"]
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# ...

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.
mice_count_regimen = mice_cleaned_data.groupby("Drug Regimen").count()["Mouse ID"].plot(kind='bar',
                                                                            xlabel="Drug Regime",
                                                                            ylabel="Number of Mice",
                                                                            title="Number of Mice per Treatment",
                                                                            facecolor="purple",figsize=(18,6),width=0.5)

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.
drug_list = mice_cleaned_data.groupby(["Drug Regimen"]).count().index.tolist()
drug__treatmen_count = (mice_cleaned_data.groupby(["Drug Regimen"])["Age_months"].count()).tolist()
plt.figure(figsize=(18,6))
plt.bar(drug_list, drug__treatmen_count,
        color='purple', alpha=1, 
        align="center", width = 0.5)

plt.title("Drug Treatment Count")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")
# Out:
# Text(0, 0.5, 'Number of Mice')

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
mice_sex = pd.DataFrame(pd.DataFrame(mice_cleaned_data.groupby(["Mouse ID","Sex"]).size()).groupby(["Sex"]).count())
mice_sex.columns = ["Total Count"]
mice_sex["values"] = (100*(mice_sex["Total Count"]/mice_sex["Total Count"].sum()))
plot = mice_sex.plot.pie(y='Total Count',
                             figsize=(6,6),
                             colors = ['orange', 'blue'],
                             startangle=60,
                             explode = (0.1, 0),
                             shadow = True, autopct="%1.1f%%")

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels = mice_sex.index.tolist()
values = mice_sex["values"] 
plt.figure(figsize=(6,6))
plt.pie(values, labels=labels,
        colors=['orange', 'blue'],
        startangle=60,
        explode=(0.1, 0),
        shadow=True,
        autopct="%1.1f%%")
plt.axis("equal")
plt.legend()
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
capomulin_df = mice_cleaned_data.loc[mice_cleaned_data["Drug Regimen"] == "Capomulin",:]
ramicane_df = mice_cleaned_data.loc[mice_cleaned_data["Drug Regimen"] == "Ramicane", :]
infubinol_df = mice_cleaned_data.loc[mice_cleaned_data["Drug Regimen"] == "Infubinol", :]
ceftamin_df = mice_cleaned_data.loc[mice_cleaned_data["Drug Regimen"] == "Ceftamin", :]

# Start by getting the last (greatest) timepoint for each mouse 
greatest_timepoint = mice_cleaned_data.groupby(["Mouse ID"])['Timepoint'].max().reset_index()

# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
mice_greatest = greatest_tp.merge(mice_cleaned_data,on=['Mouse ID','Timepoint'],how="left")
mice_greatest
# Out:
#     Mouse ID  Timepoint  index Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    463    Infubinol  Female          20          23
# 1       a251         45    473    Infubinol  Female          21          25
# 2       a262         45    483      Placebo  Female          17          29
# 3       a275         45    493     Ceftamin  Female          20          28
# 4       a366         30    500     Stelasyn  Female          16          29
# ..       ...        ...    ...          ...     ...         ...         ...
# 243     z435         10   1862     Propriva  Female          12          26
# 244     z578         45     84     Ramicane    Male          11          16
# 245     z581         45   1872    Infubinol  Female          24          25
# 246     z795         45   1882     Naftisol  Female          13          29
# 247     z969         45   1892     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
# Create empty list to fill with tumor vol data (for plotting)
all_regimens = ["Capomulin", "Ramicane", "Infubinol", "Ceftamin"]
tumor_vol_data = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for drug in all_regimens:
    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    tumor_vol = mice_greatest.loc[mice_greatest['Drug Regimen'] == drug, 'Tumor Volume (mm3)']
    
    # add subset 
    tumor_vol_data.append(tumor_vol)
    
    # Determine outliers using upper and lower bounds
    quartiles =  tumor_vol.quantile([.25,.5,.75])
    lowerq = quartiles[.25]
    upperq = quartiles[.75]
    mean =  tumor_vol.mean()
    iqr = upperq-lowerq  
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    
    outliers = tumor_vol.loc[(tumor_vol < lower_bound) 
                  | (tumor_vol > upper_bound)]
    
    print(f"<>\n",
          f"For the {drug} Regimen: \n",
          f"- The tumor's volume lower bound: {round(lowerq,2)}\n",
          f"- The tumor's volume upper bound: {round(upperq,2)}\n",
          f"- The tumor's volume IQR: {round(iqr,2)}\n",
          '----------------------------------------------------------------- \n',
          f"    - Final tumor's lower boud volume(mm3) for {drug} below {round(lower_bound,2)} could be outliers. \n",
          f"    - Final tumor volume(mm3) for {drug} above {round(upper_bound,2)} could be outliers. \n"
          f"     - Number of outliers for {drug} is: {outliers.count()}\n"
          '-----------------------------------------------------------------',)
    if outliers.count() > 0:
        for i in outliers.index:
            print(f'# Outlier final tumor volume(mm3) is {round(outliers[i], 2)}\n')
# Out:
# <>
#  For the Capomulin Regimen:
#  - The tumor's volume lower bound: 32.38
#  - The tumor's volume upper bound: 40.16
#  - The tumor's volume IQR: 7.78
#  -----------------------------------------------------------------
#      - Final tumor's lower boud volume(mm3) for Capomulin below 20.7 could be outliers.
#      - Final tumor volume(mm3) for Capomulin above 51.83 could be outliers.
#      - Number of outliers for Capomulin is: 0
# -----------------------------------------------------------------
# <>
#  For the Ramicane Regimen:
#  - The tumor's volume lower bound: 31.56
#  - The tumor's volume upper bound: 40.66
#  - The tumor's volume IQR: 9.1
#  -----------------------------------------------------------------
#      - Final tumor's lower boud volume(mm3) for Ramicane below 17.91 could be outliers.
#      - Final tumor volume(mm3) for Ramicane above 54.31 could be outliers.
#      - Number of outliers for Ramicane is: 0
# ...

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
fig1, ax1 = plt.subplots(figsize=(18, 8))
ax1.set_title('Final Tumor Volume by Drug Regimen', fontsize=18)
ax1.set_ylabel('Tumor Volume (mm3)', fontsize=12)
ax1.set_xlabel('Drug Regimens', fontsize=12)
ax1.boxplot(tumor_vol_data, flierprops = dict(markerfacecolor='k', marker='p', markersize='8'))
ax1.set_xticklabels(the4_regimens)
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
plot_line = capomulin_df.loc[capomulin_df["Mouse ID"] == "g316",:]
x_axis = plot_line["Timepoint"]
tumsiz = plot_line["Tumor Volume (mm3)"]
plt.subplots(figsize=(15, 10))
plt.title(f'Capomulin Treatment Tumor Volume over Time, Mouse ID: g316', fontsize=18)
plt.plot(x_axis, tumsiz,linewidth=2, markersize=10,marker="p",color="orange")
plt.xlabel('Timepoint (Days)', fontsize=16, color ='red')
plt.ylabel('Tumor Volume (mm3)', fontsize=16, color = 'red')

plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
mean_data =capomulin_df.loc[:,['Mouse ID', 'Weight (g)', 'Tumor Volume (mm3)']]
mean_volume = pd.DataFrame(mean_data.groupby(["Mouse ID", "Weight (g)"])["Tumor Volume (mm3)"].mean()).reset_index()

#linear regression equation and line to plot
correlation = round(st.pearsonr(mean_volume ['Weight (g)'],mean_volume ['Tumor Volume (mm3)'])[0],2)



plt.scatter( mean_volume['Weight (g)'], mean_volume['Tumor Volume (mm3)'])

plt.title("average tumor volume vs. mouse weight for the Capomulin regimen")
plt.xlabel("Mouse weight  in (g)")
plt.ylabel("Tumor Volume (mm3)")
# Out:
# Text(0, 0.5, 'Tumor Volume (mm3)')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen


#Calculating equation

correlation = st.pearsonr(x_values,y_values)
print(f"The correclation between mouse weight and average tumor volume for the Capomul regimen is {round(correlation[0],2)}")


#calculate liner regresssion
x_axis = mean_volume['Weight (g)']
y_axis = mean_volume['Tumor Volume (mm3)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.subplots(figsize=(20, 10))
plt.scatter(x_values,y_values,)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,25),color="red", fontsize=15)
plt.title(f'Average Volume Vs. Weight linear regression model', fontsize=20)
plt.xlabel('Weight(g)', fontsize=18)
plt.ylabel('Average Tumor Volume (mm3)', fontsize=18)
plt.show()
# Out:
# The correclation between mouse weight and average tumor volume for the Capomul regimen is 0.84
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [174], in <cell line: 14>()
#      12 x_axis = mean_volume['Weight (g)']
#      13 y_axis = mean_volume['Tumor Volume (mm3)']
# ---> 14 (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
#      15 regress_values = x_axis * slope + intercept
#      16 line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#
# NameError: name 'linregress' is not defined
